# %%
import pandas as pd

df = pd.read_csv("D:\Masai Assignments\Assignment  - 6\orders.csv", index_col='order_id')
print(df.head())
print('_' * 40)
print(df.info())
print('-' * 40)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# <>:3: SyntaxWarning: invalid escape sequence '\M'
# C:\Users\vemur\AppData\Local\Temp\ipykernel_25684\3318800761.py:3: SyntaxWarning: invalid escape sequence '\M'
#   df = pd.read_csv("D:\Masai Assignments\Assignment  - 6\orders.csv", index_col='order_id')
#           customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1001      Alice Johnson    Laptop       1.0     85000.0  2024-01-15  delivered
# 1002          Bob Smith     Mouse       3.0       499.0  2024-01-16    pending
# 1003        Carol White   Monitor       2.0     15000.0         NaN  delivered
# 1004         Dave Brown  Keyboard       NaN      1200.0  2024-01-18  cancelled
# 1005          Eva Green    Laptop       1.0     85000.0  2024-01-19  delivered
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 1001 to 1020
# Data columns (total 6 columns):
# ...

# %%
print(df.describe())
# Out:
#         quantity    unit_price
# count  16.000000     20.000000
# mean    2.437500  20224.600000
# std     1.504161  33573.389607
# min     1.000000    499.000000
# 25%     1.000000    799.000000
# 50%     2.000000   2500.000000
# 75%     3.000000  14625.000000
# max     6.000000  85000.000000

# %%
print(df.head(5))
print(df.tail(5))
# Out:
#           customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1001      Alice Johnson    Laptop       1.0     85000.0  2024-01-15  delivered
# 1002          Bob Smith     Mouse       3.0       499.0  2024-01-16    pending
# 1003        Carol White   Monitor       2.0     15000.0         NaN  delivered
# 1004         Dave Brown  Keyboard       NaN      1200.0  2024-01-18  cancelled
# 1005          Eva Green    Laptop       1.0     85000.0  2024-01-19  delivered
#          customer_name   product  quantity  unit_price  order_date     status
# order_id
# 1016       Paul Harris     Mouse       6.0       499.0  2024-01-30    pending
# 1017      Quinn Martin   Monitor       NaN     14500.0  2024-01-31  delivered
# 1018       Rachel King    Laptop       1.0     85000.0         NaN  delivered
# 1019        Sam Wright  Keyboard       3.0      1200.0  2024-02-01  cancelled
# 1020        Tina Baker   USB Hub       2.0       799.0  2024-02-02    pending

# %% [markdown]
# This Dataset have total 20 rows and 6 columns.
# Quantity and order_date have null values of 4 in each.
# Order_date column need convertion to date time using function "pd.to_datetime()"

# %% [markdown]
# median of unit_price =  2500.000000

# %%
df['order_date'] = pd.to_datetime(df['order_date'], errors='coerce')
print(df.head())
# Out:
#           customer_name   product  quantity  unit_price order_date     status
# order_id
# 1001      Alice Johnson    Laptop       1.0     85000.0 2024-01-15  delivered
# 1002          Bob Smith     Mouse       3.0       499.0 2024-01-16    pending
# 1003        Carol White   Monitor       2.0     15000.0        NaT  delivered
# 1004         Dave Brown  Keyboard       NaN      1200.0 2024-01-18  cancelled
# 1005          Eva Green    Laptop       1.0     85000.0 2024-01-19  delivered

# %% [markdown]
# Yes, heavily right-skewed (positive skew).
#
# Explanation using values:
#
# Mean: 20,224
#
# Median: 2,500
#
# Max: 85,000
#
# When mean >> median, it means a few large values pull the distribution to the right.
#
# This happens here because "Laptop" entries are priced at 85,000, creating extreme high outliers.
